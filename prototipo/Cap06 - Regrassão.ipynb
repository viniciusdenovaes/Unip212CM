# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 0
c = 0

# %%
def f(x):
    return a*x**2 + b*x + c

# %%
def g(x):
    return 2*x**2

# %%
x = np.linspace(-2, 2, 100)

# %%
# Out:
# array([0.00338494, 0.0225742 , 0.57044112, 0.67600518, 0.53640074,
#        0.54039561, 0.42199526, 0.94876847, 0.09558879, 0.61750866,
#        0.64285338, 0.74735342, 0.60533137, 0.77472211, 0.96383497,
#        0.47839749, 0.75784159, 0.0973143 , 0.80155482, 0.630781  ,
#        0.88618152, 0.76680578, 0.78811678, 0.26088091, 0.00905686,
#        0.40853021, 0.46327725, 0.99049778, 0.05290971, 0.36332289,
#        0.75205465, 0.80552191, 0.85343128, 0.05198677, 0.02943889,
#        0.18823334, 0.61297307, 0.64891164, 0.24544144, 0.55986102,
#        0.47818025, 0.01796237, 0.19954129, 0.75647805, 0.38747697,
#        0.56598669, 0.27729073, 0.22132081, 0.05843402, 0.93345305,
#        0.31767246, 0.24515455, 0.38910455, 0.58264702, 0.56482778,
#        0.02678877, 0.65815327, 0.02736906, 0.02692238, 0.25941606,
#        0.50574042, 0.91527506, 0.03533864, 0.77158589, 0.12883575,
#        0.96741604, 0.34619169, 0.45439986, 0.54031608, 0.05240442,
# ...

# %%
y = g(x)+np.random.rand(100)-0.5

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y)
plt.plot(x, f(x), 'r')

# %%
a = 2
b = 0
c = 0

# %%
a1 g1 = x^2 
a2 g2 = x
a3 g3 = 1
